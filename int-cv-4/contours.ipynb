# %% [markdown]
# #**Contours- Draw and find Contours**

# %%
#import requirements
import cv2
from google.colab.patches import cv2_imshow

# %%
#read the image
im = cv2.imread('tomato.jpg')
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=288x270 at 0x7F569BF00510>

# %%
#convert the image into binary by thresholding
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
a = imgray.max()  
_, thresh = cv2.threshold(imgray, a/2+60, a,cv2.THRESH_BINARY_INV)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=288x270 at 0x7F569BE71CD0>

# %%
#find and draw contours
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(im, contours, -1, (0,255,0), 3)
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=288x270 at 0x7F569BE61A10>
